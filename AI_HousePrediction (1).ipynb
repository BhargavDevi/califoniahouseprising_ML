# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # california_housing_dataset

# %%
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()

# %%
housing.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
# print the discription here 
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block group
#         - HouseAge      median house age in block group
#         - AveRooms      average number of rooms per household
#         - AveBedrms     average number of bedrooms per household
#         - Population    block group population
#         - AveOccup      average number of household members
#         - Latitude      block group latitude
#         - Longitude     block group longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# ...

# %%
print(housing.data)
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
dataset=pd.DataFrame(housing.data,columns=housing.feature_names)

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# i need a output data == prise 
dataset['Prise']=housing.target

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Prise
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Prise       20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
# summerising the stats
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Prise
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
# check the missing value
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Prise         0
# dtype: int64

# %%
# expolaratory data analysis
# correlation
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Prise       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Prise
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
plt.scatter(dataset['HouseAge'][:500], dataset['AveRooms'][:500], s=1)
plt.show()

# %%
# independent and dependent features

x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Prise
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# is an independent variable
x
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
# got my x axis [dependent variable]
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Prise, Length: 20640, dtype: float64

# %%
# train test split
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42
)

# %%
# i have cut down the dataset from 20000 to 500 to keep it easy
dataset_small=dataset.head(500)

# %%
print(dataset_small)
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0    8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1    8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2    7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3    5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4    3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ..      ...       ...       ...        ...         ...       ...       ...
# 495  5.3794      52.0  6.861017   1.123729      1316.0  2.230508     37.86
# 496  3.2619      52.0  4.792053   1.017219      1508.0  1.997351     37.85
# 497  2.7054      52.0  5.001227   1.128834      1800.0  2.208589     37.85
# 498  2.2431      47.0  6.371166   1.226994       719.0  2.205521     37.85
# 499  1.9028      50.0  5.015686   1.176471       675.0  2.647059     37.85
#
#      Longitude  Prise
# 0      -122.23  4.526
# ...

# %%
x=dataset_small.iloc[:,:-1]
y=dataset_small.iloc[:,-1]

# %%
dataset_small.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Prise
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
x
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0    8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1    8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2    7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3    5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4    3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ..      ...       ...       ...        ...         ...       ...       ...
# 495  5.3794      52.0  6.861017   1.123729      1316.0  2.230508     37.86
# 496  3.2619      52.0  4.792053   1.017219      1508.0  1.997351     37.85
# 497  2.7054      52.0  5.001227   1.128834      1800.0  2.208589     37.85
# 498  2.2431      47.0  6.371166   1.226994       719.0  2.205521     37.85
# 499  1.9028      50.0  5.015686   1.176471       675.0  2.647059     37.85
#
#      Longitude
# 0      -122.23
# 1      -122.22
# 2      -122.24
# ...

# %%
y
# Out:
# 0      4.526
# 1      3.585
# 2      3.521
# 3      3.413
# 4      3.422
#        ...
# 495    3.769
# 496    3.096
# 497    1.823
# 498    1.727
# 499    1.508
# Name: Prise, Length: 500, dtype: float64

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population   AveOccup  Latitude  \
# 5    4.0368      52.0  4.761658   1.103627       413.0   2.139896     37.85
# 116  2.4234      28.0  3.023480   1.053582      2558.0   1.540036     37.83
# 45   2.6768      52.0  4.335079   1.099476       718.0   1.879581     37.83
# 16   2.7750      52.0  5.939577   1.048338       793.0   2.395770     37.85
# 462  1.7464      35.0  3.218000   1.108000      1675.0   1.675000     37.87
# ..      ...       ...       ...        ...         ...        ...       ...
# 106  3.2727      52.0  4.442982   1.057018       709.0   1.554825     37.81
# 270  3.8750      33.0  3.021277   0.659574       575.0  12.234043     37.78
# 348  2.5043      41.0  5.465217   1.178261       828.0   3.600000     37.75
# 435  1.4750      45.0  3.306569   1.065693       749.0   5.467153     37.88
# 102  3.1250      39.0  3.745614   1.061404       389.0   1.706140     37.81
#
#      Longitude
# 5      -122.25
# 116    -122.25
# ...

# %%
y_test
# Out:
# 361    2.500
# 73     0.675
# 374    1.220
# 155    4.103
# 104    3.357
#        ...
# 266    1.439
# 23     0.997
# 222    2.730
# 261    1.216
# 426    2.875
# Name: Prise, Length: 150, dtype: float64

# %%
# standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))

# %%
x_train
# Out:
# array([[ 0.46583994,  0.80200055, -0.17425657, ..., -0.58350453,
#          0.83506471, -0.43134075],
#        [-0.50104177, -1.84507397, -1.64183849, ..., -1.18435686,
#          0.3857601 , -0.43134075],
#        [-0.34918369,  0.80200055, -0.53442698, ..., -0.84425028,
#          0.3857601 , -0.659391  ],
#        ...,
#        [-0.45255985, -0.41124193,  0.419774  , ...,  0.87901389,
#         -1.41145834,  1.39306122],
#        [-1.0694009 ,  0.02993715, -1.40281982, ...,  2.74925518,
#          1.50902163, -1.57159199],
#        [-0.08058546, -0.63183148, -1.03212477, ..., -1.01797792,
#         -0.06354451, -0.43134075]])

# %% [markdown]
# ModelTraining

# %%
from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
##print coefficient and intercept 

print(regression.coef_)
# Out:
# [ 0.4540964  -0.02275062 -0.04170356 -0.05750236  0.08066929 -0.00138917
#   0.68182581  0.30514684]

# %%
print(regression.intercept_)
# Out:
# 1.9185200857141549

# %%
##on which param model is trained.

regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
## prediction with test data


reg_pre=regression.predict(x_test)

# %%
##plot a scatter plot for prediction


plt.scatter(y_test,reg_pre)

# %%
reg_pre
# Out:
# array([2.52559351, 0.97113716, 1.45014085, 3.19893231, 1.90248745,
#        2.68487951, 1.54653777, 3.44646338, 0.66833031, 2.49483853,
#        2.43434011, 1.54747765, 3.81367912, 1.05504093, 1.38170252,
#        2.91230669, 3.02138781, 1.53611827, 0.7286755 , 3.85568703,
#        3.46952766, 2.90572716, 2.81913912, 1.44213382, 1.3278946 ,
#        2.20491997, 2.1358801 , 2.03024858, 2.04917759, 0.82854708,
#        1.9879382 , 1.17976397, 2.36671603, 1.35033557, 3.30495289,
#        0.9569461 , 4.61650325, 0.90854371, 0.99100427, 0.40676504,
#        0.87917801, 1.14086389, 2.47426837, 1.78468909, 1.32781942,
#        0.88509999, 4.20130802, 2.38377113, 3.83673206, 1.59426154,
#        0.80253167, 1.38092491, 4.76597151, 3.31039835, 0.96598745,
#        1.11094049, 1.73570502, 1.75502146, 1.29387715, 0.80098772,
#        4.11168658, 1.44823394, 0.74217527, 2.21247736, 0.94708648,
#        1.91680508, 2.21591163, 1.62948959, 1.55331668, 3.4500012 ,
# ...

# %% [markdown]
# ## Assumptions

# %%
plt.show()

# %%
##residules   [errors]

residules=y_test-reg_pre

# %%
residules
# Out:
# 361   -0.025594
# 73    -0.296137
# 374   -0.230141
# 155    0.904068
# 104    1.454513
#          ...
# 266   -0.169487
# 23    -0.747827
# 222    0.381014
# 261   -0.421175
# 426    0.169316
# Name: Prise, Length: 150, dtype: float64

# %%
##plot residules
import seaborn as sns
sns.displot(residules,kind="kde")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[94], line 2
#       1 ##plot residules
# ----> 2 import seaborn as sns
#       3 sns.displot(residules,kind="kde")
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
plt.show()

# %%
## scatter plot with resp to pre
##uniform distribution
plt.scatter(reg_pre,residules)
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("Mean Squared Error:", mean_squared_error(y_test, reg_pre))
print("Mean Absolute Error:", mean_absolute_error(y_test, reg_pre))
print(np.sqrt(mean_absolute_error(y_test, reg_pre)))

# %% [markdown]
# ##  r square and adjasters r square   one of the performance matrix

# %% [markdown]
# ## New data Prediction

# %%
housing.data[0]  #this gives the data of 2D array of one row

# %%
housing.data[0].reshape(1,-1)

# %%
 ##trnsfer of new data

scaler.transform(housing.data[0].reshape(1,-1))

# %%
regression.predict(scaler.transform(housing.data[0].reshape(1,-1)))

# %% [markdown]
# # PICKLING THE MODEL FILE FOR THE DEPLOYMENT

# %%
import pickle

# %%
pickle.dump(regression,open('regmodel.pkl','wb'))

# %%
pickle_model=pickle.load(open('regmodel.pkl','rb'))

# %%
pickle_model.predict(scaler.transform(housing.data[0].reshape(1,-1)))
